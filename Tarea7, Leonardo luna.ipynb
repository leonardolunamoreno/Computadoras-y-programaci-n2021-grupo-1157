# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardolunamoreno/Computadoras-y-programaci-n2021-grupo-1157/blob/main/Tarea7%2C%20Leonardo%20luna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 3.1 
#Se captura un dato antes de la sentencia while o repetitiva 
#y tambien despues de la sentencia y entrega del primer dato
NUM = int(input("Ingrese un número mayor que 0: ")) 
SUMPAR = 0 
SUMIMPAR = 0 
CUEPAR = 0 
NUM = 0
i = 1 
while i <= 270: 
    NUM = i 
    if NUM > 0:
        if NUM %2:
            SUMIMPAR =+ CUEPAR
            CUEPAR = CUEPAR + 1 
        else: 
            SUMIMPAR =+ NUM 
    i = i=1 
PROMPAR = SUMIMPAR / CUEPAR
print(f"El promedio de los números pares es: {PROMPAR} y la suma de los números impares es: {SUMIMPAR}")
# Out:
# Ingrese un número mayor que 0: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-a46e6454b80e> in <module>()
#      16         else:
#      17             SUMIMPAR =+ NUM
# ---> 18     i = i=1
#      19 PROMPAR = SUMIMPAR / CUEPAR
#      20 print(f"El promedio de los números pares es: {PROMPAR} y la suma de los números impares es: {SUMIMPAR}")
#
# KeyboardInterrupt:

# %% [markdown]
# proposicion inicial = un valor o algo
# while proposicion == True:
#     prop inicial
#     pi = modificacion de proposicion incial
# else:

# %%
#Problema 3.2 
BAND = 'T'
i = 2 
SUMCER = 0 
while i<= 1800: 
    SUMCER =+1
    print(i)
    if BAND == 'T':
        BAND = 'T'
        i = i+3
        
    else: 
        BAND = 'T'
        i = i+2
print(f"La suma es {SUMCER}")
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29
# 32
# 35
# 38
# 41
# 44
# 47
# 50
# 53
# 56
# 59
# 62
# 65
# 68
# 71
# 74
# 77
# 80
# 83
# 86
# 89
# 92
# 95
# 98
# 101
# 104
# 107
# 110
# 113
# 116
# 119
# 122
# 125
# 128
# 131
# 134
# 137
# 140
# 143
# 146
# 149
# 152
# 155
# 158
# 161
# 164
# 167
# 170
# 173
# 176
# 179
# 182
# 185
# 188
# 191
# 194
# 197
# 200
# 203
# 206
# 209
# 212
# 215
# 218
# 221
# 224
# 227
# 230
# 233
# 236
# 239
# 242
# 245
# 248
# 251
# 254
# 257
# 260
# 263
# 266
# 269
# 272
# 275
# 278
# 281
# 284
# 287
# 290
# 293
# 296
# 299
# 302
# 305
# 308
# 311
# 314
# 317
# 320
# 323
# 326
# 329
# 332
# 335
# 338
# 341
# 344
# 347
# 350
# 353
# 356
# 359
# 362
# 365
# 368
# 371
# 374
# 377
# 380
# 383
# 386
# 389
# 392
# 395
# 398
# 401
# 404
# 407
# 410
# 413
# 416
# 419
# 422
# 425
# 428
# 431
# 434
# 437
# 440
# 443
# 446
# 449
# 452
# 455
# 458
# 461
# 464
# 467
# 470
# 473
# 476
# 479
# 482
# 485
# 488
# 491
# 494
# 497
# 500
# 503
# 506
# 509
# 512
# 515
# ...

# %%
#Problema 3.3 
SERIE = 0 
N = int(input("Dame un número entero: "))
BAND = 'T'
i = 1
while i<= 0:
    if band == 'T':
        SERIE = SERIE + (1/i)
        BAND = 'F'
    else: 
        SERIE = SERIE - (1/i) 
        BAND = 'T' 
    i = i + 1
print(SERIE)
# Out:
# Dame un número entero: 4
# 0

# %%
#Problema 3.4 
nom = 0 
nominas = []
i = 0 
while nominas [i] > -1: 
    if nominas [i] < 1000:
        nsue = round(nominas[i]*1.15,2)
    else: 
        nsue = round(nominas[i]*1.12,2)
    nom = round(nom+nsue,2)
    i= i+1 
    print("El nuevo sueldo del trabajador es",nsue)
print("La nomina es:",nom)
